# %%
import pickle
import pandas as pd

# %% [markdown]
# # Create mp3 list for genre classes

# %% [markdown]
# ### Imports

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('track_data_trimmed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664466 entries, 0 to 664465
# Data columns (total 9 columns):
# id                 664466 non-null int64
# release_artist     664466 non-null object
# release_cat_num    663439 non-null object
# release_date       664466 non-null object
# release_genre      664466 non-null object
# release_label      664466 non-null object
# release_title      664465 non-null object
# track_name         664466 non-null object
# track_url          664466 non-null object
# dtypes: int64(1), object(8)
# memory usage: 45.6+ MB

# %% [markdown]
# ### Genre counts & map to parent genres

# %%
track_genres = df.groupby('release_genre')['id'].count().sort_values(ascending=False).reset_index()
track_genres
# Out:
#                release_genre      id
# 0         Minimal/Tech House  127504
# 1           Funky/Club House   72220
# 2                     Techno   66415
# 3                 Deep House   65465
# 4          Progressive House   57294
# 5           Uplifting Trance   31910
# 6              Electro House   30999
# 7              Drum And Bass   29175
# 8   Dirty Dubstep/Trap/Grime   16636
# 9                  Breakbeat   15450
# 10            Disco/Nu-Disco   14490
# 11      Euro Dance/Pop Dance   12719
# 12        Balearic/Downtempo   11784
# 13                Pop Trance    9801
# 14               Hip Hop/R&B    9227
# 15                 Hardstyle    7971
# 16            Psy/Goa Trance    7575
# 17               Hard Trance    6097
# 18   Experimental/Electronic    5953
# 19           Dancehall/Ragga    5414
# 20                     Gabba    5317
# 21               UK Hardcore    5025
# 22                      Bass    4983
# 23                   Electro    4543
# 24       Broken Beat/Nu Jazz    4372
# 25                     Indie    4322
# 26                 UK Garage    3885
# 27              Deep Dubstep    3189
# 28                Hard House    3046
# 29                      Rock    2688
# 30               Hard Techno    2549
# 31              Scouse House    2342
# 32                       Pop    2180
# 33             Ambient/Drone    1787
# 34                       Dub    1672
# 35                      Funk    1486
# 36         Roots/Lovers Rock    1468
# 37             Footwork/Juke    1157
# 38            Coldwave/Synth    1139
# 39                  DJ Tools     814
# 40                      Jazz     647
# 41          Industrial/Noise     459
# 42             International     434
# 43               Soundtracks     338
# 44              Classics/Ska     192
# 45                      Soul     183
# 46                 Leftfield      88
# 47                   50s/60s      51
# 48                Rock (All)       8
# 49              Unclassified       3

# %% [markdown]
# Lots of genres, and lots with too few songs.

# %% [markdown]
# I'm going to map some of these smaller genres to a bigger parent genre and then remove ones that I'm not going to use.

# %%
def parent_genre(s):
    
    parent_genres = {
    'Minimal/Tech House':'Minimal House',
    'Progressive House':'Progressive House',
    'Funky/Club House':'Funky House',
    'Deep House':'Deep House',
    'Techno':'Techno',
    'Uplifting Trance':'Trance',
    'Electro House':'Electro House',
    'Drum And Bass':'Drum And Bass',
    'Dirty Dubstep/Trap/Grime':'Dubstep/Grime',
    'Breakbeat':'Breakbeat',
    'Disco/Nu-Disco':'Disco',
    'Balearic/Downtempo':'Downtempo',
    'Euro Dance/Pop Dance':'Euro Dance',
    'Hip Hop/R&B':'Hip Hop/R&B',
    'Hardstyle':'Not Needed',
    'Psy/Goa Trance':'Not Needed',
    'Dancehall/Ragga':'Dancehall/Ragga',
    'Hard Trance':'Hard Trance',
    'Indie':'Rock/Indie',
    'UK Hardcore':'Not Needed',
    'Hard House':'Hard House',
    'Experimental/Electronic':'Not Needed',
    'Pop Trance':'Not Needed',
    'Bass':'Not Needed',
    'Broken Beat/Nu Jazz':'Not Needed',
    'Rock':'Rock/Indie',
    'Gabba':'Not Needed',
    'Pop':'Pop',
    'UK Garage':'UK Garage',
    'Electro':'Not Needed',
    'Deep Dubstep':'Dubstep/Grime',
    'Roots/Lovers Rock':'Not Needed',
    'Hard Techno':'Not Needed',
    'Ambient/Drone':'Not Needed',
    'Funk':'Not Needed',
    'Scouse House':'Not Needed',
    'Dub':'Not Needed',
    'Coldwave/Synth':'Not Needed',
    'Jazz':'Not Needed',
    'DJ Tools':'Not Needed',
    'Industrial/Noise':'Not Needed',
    'Footwork/Juke':'Not Needed',
    'Classics/Ska':'Not Needed',
    'International':'Not Needed',
    'Soul':'Not Needed',
    'Soundtracks':'Not Needed',
    'Leftfield':'Not Needed',
    '50s/60s':'Not Needed',
    'Rock (All)':'Rock/Indie',
    'Unclassified':'Not Needed'
    }
    
    parent = parent_genres[s]
    return parent

# %%
df['parent_genre'] = df['release_genre'].apply(parent_genre)

# %%
df.head()
# Out:
#    id           release_artist  release_cat_num release_date  \
# 0   0      DJ SNAKE feat G4SHI  006025 57534641    22 Mar 17
# 1   1  CLEAR VIEW feat JESSICA         SB 215-0    10 Sep 08
# 2   2  CLEAR VIEW feat JESSICA         SB 215-0    10 Sep 08
# 3   3                  _LINDEN       AED 0027DL    05 Feb 16
# 4   4                  _LINDEN       AED 0027DL    05 Feb 16
#
#        release_genre     release_label                      release_title  \
# 0      Electro House           Polydor  4 Life (Explicit Habstrakt Remix)
# 1  Progressive House  Songbird Holland                            Tell Me
# 2  Progressive House  Songbird Holland                            Tell Me
# 3               Rock               AED                 Bones/Broken Glass
# 4               Rock               AED                 Bones/Broken Glass
#
#                             track_name  \
# 0    4 Life (Habstrakt remix) - (3:30)
# 1                     Tell Me - (6:43)
# 2  Tell Me (Max Graham remix) - (8:49)
# 3                       Bones - (3:17)
# 4                Broken Glass - (3:00)
#
#                                            track_url       parent_genre
# 0  https://www.junodownload.com/MP3/SF3376865-02-...      Electro House
# 1  https://www.junodownload.com/MP3/SF1354749-02-...  Progressive House
# 2  https://www.junodownload.com/MP3/SF1354749-02-...  Progressive House
# 3  https://www.junodownload.com/MP3/SF3007568-02-...         Rock/Indie
# 4  https://www.junodownload.com/MP3/SF3007568-02-...         Rock/Indie

# %% [markdown]
# Look at the genres based on newly created parent genre...

# %%
df.groupby('parent_genre')['id'].count().sort_values(ascending=False).reset_index()
# Out:
#          parent_genre      id
# 0       Minimal House  127504
# 1          Not Needed   72349
# 2         Funky House   72220
# 3              Techno   66415
# 4          Deep House   65465
# 5   Progressive House   57294
# 6              Trance   31910
# 7       Electro House   30999
# 8       Drum And Bass   29175
# 9       Dubstep/Grime   19825
# 10          Breakbeat   15450
# 11              Disco   14490
# 12         Euro Dance   12719
# 13          Downtempo   11784
# 14        Hip Hop/R&B    9227
# 15         Rock/Indie    7018
# 16        Hard Trance    6097
# 17    Dancehall/Ragga    5414
# 18          UK Garage    3885
# 19         Hard House    3046
# 20                Pop    2180

# %% [markdown]
# Remove the not needed 'genre'

# %%
not_needed = df[df['parent_genre'] == 'Not Needed']
df = df.drop(not_needed.index)
df.groupby('parent_genre')['id'].count().sort_values(ascending=False).reset_index()
# Out:
#          parent_genre      id
# 0       Minimal House  127504
# 1         Funky House   72220
# 2              Techno   66415
# 3          Deep House   65465
# 4   Progressive House   57294
# 5              Trance   31910
# 6       Electro House   30999
# 7       Drum And Bass   29175
# 8       Dubstep/Grime   19825
# 9           Breakbeat   15450
# 10              Disco   14490
# 11         Euro Dance   12719
# 12          Downtempo   11784
# 13        Hip Hop/R&B    9227
# 14         Rock/Indie    7018
# 15        Hard Trance    6097
# 16    Dancehall/Ragga    5414
# 17          UK Garage    3885
# 18         Hard House    3046
# 19                Pop    2180

# %% [markdown]
# ### Sample 1,000 songs for each genre

# %% [markdown]
# I want to take a sample of 1000 songs for each genre.

# %%
df_trimmed = df[(df['parent_genre'] != 'Pop') & (df['parent_genre'] != 'UK Garage')]
df_trimmed.groupby('parent_genre')['id'].count().sort_values(ascending=False).reset_index()
# Out:
#          parent_genre      id
# 0       Minimal House  127504
# 1         Funky House   72220
# 2              Techno   66415
# 3          Deep House   65465
# 4   Progressive House   57294
# 5              Trance   31910
# 6       Electro House   30999
# 7       Drum And Bass   29175
# 8       Dubstep/Grime   19825
# 9           Breakbeat   15450
# 10              Disco   14490
# 11         Euro Dance   12719
# 12          Downtempo   11784
# 13        Hip Hop/R&B    9227
# 14         Rock/Indie    7018
# 15        Hard Trance    6097
# 16    Dancehall/Ragga    5414
# 17         Hard House    3046

# %%
grouped = df_trimmed.groupby('parent_genre', as_index=False)
equal_sample_df = grouped.apply(lambda x: x.sample(1000)).reset_index()
equal_sample_df.drop(['level_0','level_1'], axis=1, inplace=True)

# %%
equal_sample_df.groupby('parent_genre')['id'].count().sort_values(ascending=False).reset_index()
# Out:
#          parent_genre    id
# 0              Trance  1000
# 1              Techno  1000
# 2     Dancehall/Ragga  1000
# 3          Deep House  1000
# 4               Disco  1000
# 5           Downtempo  1000
# 6       Drum And Bass  1000
# 7       Dubstep/Grime  1000
# 8       Electro House  1000
# 9          Euro Dance  1000
# 10        Funky House  1000
# 11         Hard House  1000
# 12        Hard Trance  1000
# 13        Hip Hop/R&B  1000
# 14      Minimal House  1000
# 15  Progressive House  1000
# 16         Rock/Indie  1000
# 17          Breakbeat  1000

# %% [markdown]
# ### Save data

# %%
equal_sample_df.to_pickle('final_data.pkl')
